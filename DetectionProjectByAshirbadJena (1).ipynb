# %%
# !pip install ultralytics

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
import cv2
from google.colab.patches import cv2_imshow

frame = cv2.imread('/content/maxresdefault.jpeg')

cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=320x180>

# %%
from ultralytics import YOLO
from PIL import Image
import cv2

model = YOLO("yolov8n.pt")
im1 = Image.open("/content/maxresdefault.jpeg")
results = model.predict(source=im1, save=True)
im2 = cv2.imread("/content/maxresdefault.jpeg")
results = model.predict(source=im2, save=True, save_txt=True)

results = model.predict(source=[im1, im2])
# Out:
# 0: 384x640 7 persons, 12.6ms
# Speed: 1.8ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict10
#
# 0: 384x640 7 persons, 12.5ms
# Speed: 2.2ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict10
# 1 label saved to runs/detect/predict10/labels
#
# 0: 384x640 7 persons, 6.8ms
# 1: 384x640 7 persons, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict10
# 3 labels saved to runs/detect/predict10/labels

# %%
def invoice_provided(results):
  for result in results[0].names.values():
    if "invoice" in result:
      return True
  return False

if 'person' in results[0].names.values():
  if invoice_provided(results):
    print("No alert needed. Invoice provided.")
  else:
    print("Alert generated. Invoice not provided.")
else:
  print("No person detected with the invoice")
# Out:
# Alert generated. Invoice not provided.

# %%
cv2.imread('/content/runs/detect/predict9/image0.jpg')
# Out:
# array([[[ 88,  89,  80],
#         [ 90,  91,  82],
#         [ 84,  85,  76],
#         ...,
#         [171, 169, 175],
#         [137, 127, 143],
#         [102,  92, 109]],
#
#        [[ 22,  23,  14],
#         [ 26,  27,  18],
#         [ 39,  40,  31],
#         ...,
#         [139, 137, 143],
#         [118, 111, 124],
#         [108, 100, 117]],
#
#        [[ 51,  48,  43],
#         [ 42,  39,  34],
#         [ 19,  16,  11],
#         ...,
#         [144, 144, 150],
#         [ 94,  90, 102],
#         [ 49,  44,  59]],
#
#        ...,
#
#        [[ 84,  56,  55],
#         [ 55,  24,  25],
#         [166, 129, 133],
#         ...,
#         [ 92,  70,  75],
#         [117,  96, 111],
#         [143, 122, 144]],
#
#        [[172, 144, 143],
#         [114,  83,  84],
#         [114,  77,  81],
#         ...,
#         [ 92,  70,  75],
#         [121, 100, 115],
#         [150, 129, 151]],
#
#        [[139, 111, 110],
#         [236, 205, 206],
#         [155, 118, 122],
# ...

# %%
results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
